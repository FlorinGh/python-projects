# %% [markdown]
# # Extracting text from PDFs

# %% [markdown]
# ## Challenge:
# Use python and its libraries to extract the titles of pdf drawings and save them in an excel file.

# %% [markdown]
# ## Action plan:
#
# 1. Take one pdf sample and print to the console the title of the drawing
# 2. Write the title in an excel file in a certain cell
# 3. Make everything run in a loop to record all pdf files in a folder
# 4. Make an executable take can run automatically

# %%
import PyPDF2
pdfFileObj = open('M-05-sample.pdf', 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
pdfReader.numPages
# Out:
# 1

# %%
pageObj = pdfReader.getPage(0)
pdfContentString = pageObj.extractText()

# %%
pdfContentList = pdfContentString.split()
pdfContentList
# Out:
# ['NOTES:1.THIS',
#  'DRAWING',
#  'SHOULD',
#  'BE',
#  'READ',
#  'IN',
#  'CONJUNCTION',
#  'WITH',
#  'JSH',
#  'MECHANICAL',
#  'SERVICES',
#  'SPECIFICATION',
#  'REF:',
#  'NR/PB/5429/M.LEGEND:PIPEWORK',
#  'RUN',
#  'IN',
#  'CEILING',
#  'VOID',
#  '(CV)',
#  'PIPEWORK',
#  'RUN',
#  'AT',
#  'HIGH',
#  'LEVEL',
#  '(HL)',
#  'PIPEWORK',
#  'RUN',
#  'AT',
#  'LOW',
#  'LEVEL',
#  '(LL)',
#  'PIPEWORK',
#  'RUN',
#  'BELOW',
#  'GROUND',
#  'LEVEL',
#  '(UG)',
#  'PIPEWORK',
#  'DROP',
#  '/',
#  'RISEWATER',
#  'FLOW',
#  'DIRECTION',
#  'ARROWPANEL',
#  'RADIATOR,',
#  'c/w',
#  'TRVFAN',
#  'CONVECTOR,',
#  'FLOOR/WALL',
#  'MOUNTED',
#  'FAN',
#  'CONVECTOR',
#  'AIR',
#  'FLOW',
#  'DIRECTION',
#  'ARROWxxxEQUIPMENT',
#  'REFERENCE2-WAY',
#  'GAS',
#  'TAP4-WAY',
#  'GAS',
#  'TAPEMERGENCY',
#  'KNOCK',
#  'OFF',
#  'BUTTONEKOB"A""A"ANCHOR',
#  'POINTLST',
#  'RADIATOR,',
#  'c/w',
#  'TRVGGAS',
#  'CONTROL',
#  'UNIT',
#  'WITH',
#  'BUILT-IN',
#  'KNOCK',
#  'OFF',
# ...

# %%
for i in range(len(pdfContentList)):
    if 'SHEET' in pdfContentList[i]:
        print(i, pdfContentList[i])
# Out:
# 339 1:1000SHEET
# 377 LAYOUTSHEET

# %% [markdown]
# ---

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from cStringIO import StringIO

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = file(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text
print(convert_pdf_to_txt('M-05-sample.pd'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-6187f7cdf74e> in <module>()
# ----> 1 from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
#       2 from pdfminer.converter import TextConverter
#       3 from pdfminer.layout import LAParams
#       4 from pdfminer.pdfpage import PDFPage
#       5 from cStringIO import StringIO
#
# ModuleNotFoundError: No module named 'pdfminer'
